# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
import json


url = 'https://www.fairobserver.com'

response = requests.get(url)


if response.status_code == 200:
    print("Page successfully retrieved")


    soup = BeautifulSoup(response.text, 'html.parser')


    articles = soup.find_all('article')


    article_data = []


    for article in articles:

        title = article.find('h2').text.strip() if article.find('h2') else 'No title available'

        link = article.find('a')['href'] if article.find('a') else 'No link available'

        date = article.find('time').text.strip() if article.find('time') else 'No date available'


        article_info = {
            'title': title,
            'link': link,
            'date': date
        }

        article_data.append(article_info)


    with open('fairobserver_articles.json', 'w') as f:
        json.dump(article_data, f, indent=4)


    print(json.dumps(article_data, indent=4))

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Page successfully retrieved
# [
#     {
#         "title": "Swapping Sex: A Timeline of Transgender Trailblazers",
#         "link": "https://www.fairobserver.com/interactive/swapping-sex-a-timeline-of-transgender-trailblazers/",
#         "date": "No date available"
#     },
#     {
#         "title": "FO\u00b0 Exclusive: Rachel Reeves Delivers Important Post-Brexit Budget",
#         "link": "https://www.fairobserver.com/politics/fo-exclusive-rachel-reeves-delivers-important-post-brexit-budget/",
#         "date": "No date available"
#     },
#     {
#         "title": "Making Sense of South Africa\u2019s Rich History",
#         "link": "https://www.fairobserver.com/history/making-sense-of-south-africas-rich-history/",
#         "date": "No date available"
#     },
#     {
#         "title": "No title available",
#         "link": "https://www.fairobserver.com/product/fair-observer-monthly-september-2024/",
#         "date": "No date available"
#     },
#     {
# ...
